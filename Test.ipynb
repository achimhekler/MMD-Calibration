# %%
from utils.dataset import get_loaders
import matplotlib.pyplot as plt
import numpy as np
from utils.utils import set_seed

# %%
set_seed(42)

# %%
train_loader, val_loader, test_loader,testset = get_loaders(
    name="cifar10",
    data_root="/omics/groups/OE0603/internal/hekler/data/cifar10",
    batch_size=100,
    train_no_aug=True,
)
# Out:
# No aug.

# %%
def show_image(image, label):
    plt.imshow(np.transpose(image.numpy(), (1, 2, 0)))
    plt.title(f"Label: {label}")
    plt.show()

# %%
for images, labels in train_loader:
#    # Hier können Sie Code hinzufügen, um die Bilder anzuzeigen
    i = 1
    show_image(images[i,:,:,:], labels[i])
    print(images.shape)
    break  # Stoppen Sie nach dem ersten Batch
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# torch.Size([100, 3, 32, 32])

# %%
for images, labels in val_loader:
#    # Hier können Sie Code hinzufügen, um die Bilder anzuzeigen
    i = 1
    show_image(images[i,:,:,:], labels[i])
    print(images.shape)
    break  # Stoppen Sie nach dem ersten Batch
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# torch.Size([100, 3, 32, 32])

# %%
for images, labels in test_loader:
#    # Hier können Sie Code hinzufügen, um die Bilder anzuzeigen
    i = 1
    show_image(images[i,:,:,:], labels[i])
    print(images.shape)
    break  # Stoppen Sie nach dem ersten Batch
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# torch.Size([100, 3, 32, 32])
